# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
root = Path.cwd().parent

# %%
logs = sorted(root.joinpath('results').glob('**/coteaching_plus/*0.5.txt'))
log1 = [pd.read_csv(p, sep=' ') for p in logs]
logs
# Out:
# [PosixPath('/projects/coteaching_plus/results/trial_1/news/coteaching_plus/news_coteaching_plus_symmetric_0.5.txt'),
#  PosixPath('/projects/coteaching_plus/results/trial_2/news/coteaching_plus/news_coteaching_plus_symmetric_0.5.txt'),
#  PosixPath('/projects/coteaching_plus/results/trial_3/news/coteaching_plus/news_coteaching_plus_symmetric_0.5.txt'),
#  PosixPath('/projects/coteaching_plus/results/trial_4/news/coteaching_plus/news_coteaching_plus_symmetric_0.5.txt'),
#  PosixPath('/projects/coteaching_plus/results/trial_5/news/coteaching_plus/news_coteaching_plus_symmetric_0.5.txt')]

# %%
logs = sorted(root.joinpath('results').glob('**/coteaching_plus/*0.5_30_40.txt'))
log2 = [pd.read_csv(p, sep=' ') for p in logs]
logs
# Out:
# [PosixPath('/projects/coteaching_plus/results/trial_1/news/coteaching_plus/news_coteaching_plus_symmetric_0.5_30_40.txt'),
#  PosixPath('/projects/coteaching_plus/results/trial_2/news/coteaching_plus/news_coteaching_plus_symmetric_0.5_30_40.txt'),
#  PosixPath('/projects/coteaching_plus/results/trial_3/news/coteaching_plus/news_coteaching_plus_symmetric_0.5_30_40.txt'),
#  PosixPath('/projects/coteaching_plus/results/trial_4/news/coteaching_plus/news_coteaching_plus_symmetric_0.5_30_40.txt'),
#  PosixPath('/projects/coteaching_plus/results/trial_5/news/coteaching_plus/news_coteaching_plus_symmetric_0.5_30_40.txt')]

# %%
for info in log1:
    plt.plot(info['test_acc1'], color='r')
    plt.plot(info['test_acc2'], color='r')
for info in log2:
    plt.plot(info['test_acc1'], color='g')
    plt.plot(info['test_acc2'], color='g')

# %%
for info in log1:
    plt.plot(info['test_acc1'], color='r')
    plt.plot(info['test_acc2'], color='r')

# %%
for info in log2:
    plt.plot(info['test_acc1'], color='g')
    plt.plot(info['test_acc2'], color='g')
